# %% [markdown]
# # Plantalyze model - Arquitectura 2 v2
# Modelo de machine learning para detección de especies de plantas a partir de imágenes.

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import kagglehub

# %% [markdown]
#  # Hiperparámetros

# %%
IMG_WIDTH, IMG_HEIGHT = 224, 224
BATCH_SIZE = 32
LEARNING_RATE = 0.0002
EPOCHS = 50

# %% [markdown]
# ### Importar dataset

# %%
path = kagglehub.dataset_download("marquis03/plants-classification")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/marquis03/plants-classification/versions/1

# %% [markdown]
# Nota: Este dataset ya estaba separado con una distribución de **70/20/10**, 70% train, 20% test y 10% validation.

# %%
train_dir = path + "/train"
test_dir = path + "/test"
val_dir = path + "/val"

# %% [markdown]
# ### Redimensionar + Data Augmentation
# Redimensionar todas las imágenes de 224x224. Además de añadir data augmentation con los datos de train.

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 10,
    width_shift_range = 0.2,
    zoom_range = 0.3,
    horizontal_flip = True
    )

datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_WIDTH, IMG_HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_WIDTH, IMG_HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_WIDTH, IMG_HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

images , labels = train_generator[0]

print(images.shape)

plt.figure()
f, axarr = plt.subplots(1, images.shape[0], figsize=(30, 4))

for i in range(images.shape[0]) :
  axarr[i].imshow(images[i])
# Out:
# Found 21000 images belonging to 30 classes.
# Found 6000 images belonging to 30 classes.
# Found 3000 images belonging to 30 classes.
# (32, 224, 224, 3)

# %%
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D,
    MaxPooling2D,
    Flatten,
    Dense,
    Input,
    Reshape
)

def get_model_compiled():
  model = Sequential()
  model.add(Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3)))

  model.add(Conv2D(16, kernel_size=3, activation="relu", padding="same"))
  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Conv2D(32, kernel_size=3, activation="relu", padding="same"))
  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Conv2D(64, kernel_size=3, activation="relu", padding="same"))
  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Conv2D(128, kernel_size=3, activation="relu", padding="same"))
  model.add(MaxPooling2D(pool_size=(2, 2)))

  model.add(Flatten())

  model.add(Dense(30, activation="softmax"))

  model.compile(optimizer="adam",
                loss="categorical_crossentropy",
                metrics=["accuracy"])

  return model

# %%
model = get_model_compiled()
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)               │ (None, 224, 224, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 112, 112, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 56, 56, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 30)             │       752,670 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 850,110 (3.24 MB)
#  Trainable params: 850,110 (3.24 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Plantalyze
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Plantalyze

# %%
current_directory = "/content/drive/MyDrive/Plantalyze"
checkpoint_path = current_directory + "/checkpoints/checkpoint_arq2_v2.weights.h5"
checkpoint = ModelCheckpoint(filepath=checkpoint_path,
                             save_freq= "epoch",
                             save_weights_only = True,
                             verbose = 1)
early_stop = EarlyStopping(monitor='val_loss', patience=5)

# %%
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    callbacks=[checkpoint, early_stop])
# Out:
# Epoch 1/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.2843 - loss: 2.4330
# Epoch 1: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 1: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 262s 399ms/step - accuracy: 0.3049 - loss: 2.3491 - val_accuracy: 0.3867 - val_loss: 2.0906
# Epoch 2/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.3566 - loss: 2.1583
# Epoch 2: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 2: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 260s 396ms/step - accuracy: 0.3747 - loss: 2.1082 - val_accuracy: 0.4600 - val_loss: 1.8206
# Epoch 3/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.4206 - loss: 1.9490
# Epoch 3: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 3: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 260s 395ms/step - accuracy: 0.4243 - loss: 1.9338 - val_accuracy: 0.4937 - val_loss: 1.7240
# Epoch 4/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.4595 - loss: 1.8327
# Epoch 4: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 4: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 260s 396ms/step - accuracy: 0.4590 - loss: 1.8359 - val_accuracy: 0.5250 - val_loss: 1.6350
# Epoch 5/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.4802 - loss: 1.7526
# Epoch 5: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 5: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 259s 395ms/step - accuracy: 0.4840 - loss: 1.7513 - val_accuracy: 0.5247 - val_loss: 1.5986
# Epoch 6/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.5024 - loss: 1.6819
# Epoch 6: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 6: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 260s 396ms/step - accuracy: 0.5053 - loss: 1.6664 - val_accuracy: 0.5433 - val_loss: 1.6236
# Epoch 7/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.5229 - loss: 1.6045
# Epoch 7: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 7: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 257s 392ms/step - accuracy: 0.5338 - loss: 1.5819 - val_accuracy: 0.5793 - val_loss: 1.4883
# Epoch 8/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.5407 - loss: 1.5363
# Epoch 8: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 8: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 261s 397ms/step - accuracy: 0.5476 - loss: 1.5197 - val_accuracy: 0.5930 - val_loss: 1.4747
# Epoch 9/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.5682 - loss: 1.4586
# Epoch 9: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 9: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 261s 397ms/step - accuracy: 0.5657 - loss: 1.4522 - val_accuracy: 0.5807 - val_loss: 1.4264
# Epoch 10/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.5893 - loss: 1.3831
# Epoch 10: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 10: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 260s 396ms/step - accuracy: 0.5846 - loss: 1.3999 - val_accuracy: 0.5813 - val_loss: 1.4786
# Epoch 11/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.5915 - loss: 1.3588
# Epoch 11: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 11: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 260s 395ms/step - accuracy: 0.5899 - loss: 1.3665 - val_accuracy: 0.6357 - val_loss: 1.3101
# Epoch 12/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.6072 - loss: 1.3035
# Epoch 12: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 12: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 260s 395ms/step - accuracy: 0.6049 - loss: 1.3130 - val_accuracy: 0.6213 - val_loss: 1.3605
# Epoch 13/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.6180 - loss: 1.2796
# Epoch 13: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 13: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 258s 392ms/step - accuracy: 0.6150 - loss: 1.2865 - val_accuracy: 0.6367 - val_loss: 1.2780
# Epoch 14/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.6210 - loss: 1.2419
# Epoch 14: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 14: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 259s 395ms/step - accuracy: 0.6218 - loss: 1.2384 - val_accuracy: 0.6293 - val_loss: 1.3891
# Epoch 15/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.6349 - loss: 1.2127
# Epoch 15: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 15: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 259s 395ms/step - accuracy: 0.6314 - loss: 1.2213 - val_accuracy: 0.6273 - val_loss: 1.3612
# Epoch 16/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.6381 - loss: 1.1779
# Epoch 16: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 16: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 262s 398ms/step - accuracy: 0.6360 - loss: 1.1869 - val_accuracy: 0.6637 - val_loss: 1.2183
# Epoch 17/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.6493 - loss: 1.1412
# Epoch 17: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 17: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 259s 394ms/step - accuracy: 0.6424 - loss: 1.1749 - val_accuracy: 0.6600 - val_loss: 1.2433
# Epoch 18/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.6556 - loss: 1.1245
# Epoch 18: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 18: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 260s 396ms/step - accuracy: 0.6521 - loss: 1.1433 - val_accuracy: 0.6587 - val_loss: 1.1955
# Epoch 19/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.6627 - loss: 1.1027
# Epoch 19: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 19: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 259s 394ms/step - accuracy: 0.6556 - loss: 1.1220 - val_accuracy: 0.6410 - val_loss: 1.2679
# Epoch 20/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.6692 - loss: 1.0604
# Epoch 20: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 20: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 261s 397ms/step - accuracy: 0.6657 - loss: 1.0917 - val_accuracy: 0.6427 - val_loss: 1.3411
# Epoch 21/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.6720 - loss: 1.0779
# Epoch 21: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 21: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 260s 396ms/step - accuracy: 0.6699 - loss: 1.0869 - val_accuracy: 0.6650 - val_loss: 1.2133
# Epoch 22/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.6786 - loss: 1.0425
# Epoch 22: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 22: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 259s 395ms/step - accuracy: 0.6782 - loss: 1.0556 - val_accuracy: 0.6710 - val_loss: 1.2233
# Epoch 23/50
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.6821 - loss: 1.0184
# Epoch 23: saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
#
# Epoch 23: finished saving model to /content/drive/MyDrive/Plantalyze/checkpoints/checkpoint_arq2_v2.weights.h5
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 260s 396ms/step - accuracy: 0.6794 - loss: 1.0385 - val_accuracy: 0.6653 - val_loss: 1.3012

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(acc) + 1)

plt.plot(epochs_range, acc, "bo", label="Training accuracy")
plt.plot(epochs_range, val_acc, "r", label="Validation accuracy")
plt.title("Train vs Validation Accuracy")
plt.legend()

plt.figure()

plt.plot(epochs_range, loss, "bo", label="Training loss")
plt.plot(epochs_range, val_loss, "r", label="Validation loss")
plt.title("Train vs Validation Loss")
plt.legend()

plt.show()

# %%
test_loss, test_acc = model.evaluate(test_generator)
print(f"Test accuracy: {test_acc}")
print(f"Test loss: {test_loss}")

predictions = model.predict(test_generator)
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.6333 - loss: 1.3390
# Test accuracy: 0.6333333253860474
# Test loss: 1.3390297889709473
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 15s 74ms/step

# %%
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

class_names = list(test_generator.class_indices.keys())

report = classification_report(
    y_true,
    y_pred,
    target_names=class_names,
)


conf_matrix = confusion_matrix(y_true, y_pred)

print("Classification Report:")
print(report)

plt.figure(figsize=(10, 10))
sns.heatmap(
    conf_matrix,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names,
)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#      aloevera       0.78      0.76      0.77       200
#        banana       0.61      0.29      0.39       200
#       bilimbi       0.62      0.44      0.51       200
#    cantaloupe       0.41      0.66      0.51       200
#       cassava       0.61      0.66      0.63       200
#       coconut       0.55      0.35      0.43       200
#          corn       0.47      0.85      0.60       200
#      cucumber       0.81      0.69      0.74       200
#       curcuma       0.69      0.74      0.72       200
#      eggplant       0.69      0.83      0.75       200
#      galangal       0.80      0.73      0.76       200
#        ginger       0.55      0.58      0.57       200
#         guava       0.59      0.70      0.64       200
#          kale       0.72      0.58      0.65       200
#     longbeans       0.87      0.65      0.74       200
#         mango       0.41      0.33      0.36       200
#         melon       0.35      0.14      0.19       200
#        orange       0.64      0.40      0.49       200
#         paddy       0.65      0.81      0.72       200
#        papaya       0.85      0.87      0.86       200
#    peperchili       0.79      0.80      0.80       200
#     pineapple       0.70      0.65      0.67       200
#        pomelo       0.57      0.64      0.60       200
#       shallot       0.60      0.59      0.59       200
#      soybeans       0.70      0.63      0.66       200
#       spinach       0.57      0.59      0.58       200
# sweetpotatoes       0.53      0.81      0.64       200
#       tobacco       0.54      0.58      0.56       200
#    waterapple       0.66      0.81      0.73       200
#    watermelon       0.91      0.85      0.88       200
#
#      accuracy                           0.63      6000
#     macro avg       0.64      0.63      0.63      6000
#  weighted avg       0.64      0.63      0.63      6000
